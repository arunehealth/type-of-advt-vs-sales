# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [raw]
# data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv')

# %%
data.head(2)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4

# %%
data.shape
# Out:
# (200, 5)

# %%
data.isnull()

# %%
data.describe()

# %%
sns.pairplot(data, x_vars=['TV','radio','newspaper'], y_vars='sales')

# %%
sns.pairplot(data,x_vars=['TV','radio','newspaper'], y_vars='sales', size=7, aspect=0.7, kind='reg')

# %%
sns.pairplot(data,x_vars=['TV','radio','newspaper'], y_vars='sales', size=9, aspect=0.7, kind='scatter')

# %%
x = data.loc[:,['TV','radio','newspaper']]

# %%
y =data.iloc[:,[-1]]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, random_state=1)

# %%
x_train.shape
# Out:
# (150, 3)

# %%
x_test.shape
# Out:
# (50, 3)

# %%
y_train.shape
# Out:
# (150, 1)

# %%
y_test.shape
# Out:
# (50, 1)

# %% [markdown]
# ####instantiate

# %%
linreg=LinearRegression()

# %%
linreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linreg.intercept_
# Out:
# array([2.87696662])

# %%
linreg.coef_
# Out:
# array([[0.04656457, 0.17915812, 0.00345046]])

# %% [markdown]
# what is linear coefficient?
# y = 2.88+ 0.0466*TV+0.179*radio + 0.00345*newspaper
# for eg. for every unit of increase in TV spendin the sales increase by 0.0466 units

# %%
y_pred = linreg.predict(x_test)

# %%
y_pred
# Out:
# array([[21.70910292],
#        [16.41055243],
#        [ 7.60955058],
#        [17.80769552],
#        [18.6146359 ],
#        [23.83573998],
#        [16.32488681],
#        [13.43225536],
#        [ 9.17173403],
#        [17.333853  ],
#        [14.44479482],
#        [ 9.83511973],
#        [17.18797614],
#        [16.73086831],
#        [15.05529391],
#        [15.61434433],
#        [12.42541574],
#        [17.17716376],
#        [11.08827566],
#        [18.00537501],
#        [ 9.28438889],
#        [12.98458458],
#        [ 8.79950614],
#        [10.42382499],
#        [11.3846456 ],
#        [14.98082512],
#        [ 9.78853268],
#        [19.39643187],
#        [18.18099936],
#        [17.12807566],
#        [21.54670213],
#        [14.69809481],
#        [16.24641438],
#        [12.32114579],
#        [19.92422501],
#        [15.32498602],
#        [13.88726522],
#        [10.03162255],
#        [20.93105915],
#        [ 7.44936831],
#        [ 3.64695761],
# ...

# %% [markdown]
# to check the y_pred values

# %%
arun = list(zip(y_pred, y_test))

# %%
arun
# Out:
# [(array([21.70910292]), 'sales')]

# %%
y_test
# Out:
#      sales
# 58    23.8
# 40    16.6
# 34     9.5
# 102   14.8
# 184   17.6
# 198   25.5
# 95    16.9
# 4     12.9
# 29    10.5
# 168   17.1
# 171   14.5
# 18    11.3
# 11    17.4
# 89    16.7
# 110   13.4
# 118   15.9
# 159   12.9
# 35    12.8
# 136    9.5
# 59    18.4
# 51    10.7
# 16    12.5
# 44     8.5
# 94    11.5
# 31    11.9
# 162   14.9
# 38    10.1
# 28    18.9
# 193   19.6
# 27    15.9
# 47    23.2
# 165   11.9
# 194   17.3
# 177   11.7
# 176   20.2
# 97    15.5
# 174   11.5
# 73    11.0
# 69    22.3
# 172    7.6
# 108    5.3
# 107    8.7
# 189    6.7
# 14    19.0
# 56     5.5
# 19    14.6
# 114   14.6
# 39    21.5
# 185   22.6
# 124   19.7

# %%
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 1.0668917082595206

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 1.9730456202283364

# %%
np.sqrt(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 1.4046514230328948

# %%
x1 = data.loc[:,['TV']]

# %%
y1 = data.iloc[:,-1]

# %%
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1, random_state=1)

# %%
x1_train.shape
# Out:
# (150, 1)

# %%
linreg.fit(x1_train,y1_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linreg.intercept_
# Out:
# 6.91197261886872

# %%
linreg.coef_
# Out:
# array([0.04802945])

# %%
y1_pred = linreg.predict(x1_test)

# %%
arun1 = list(zip(y1_pred,y1_test))

# %%
arun1 = list(zip(y1_pred, y1_test))

# %%
arun1
# Out:
# [(17.03658068894331, 23.8),
#  (16.637936253546634, 16.6),
#  (11.50839098844243, 9.5),
#  (20.369824522260085, 14.8),
#  (19.101847040998372, 17.6),
#  (20.53312465242258, 25.5),
#  (14.755181811673182, 16.9),
#  (15.595697187509545, 12.9),
#  (10.302851792242848, 10.5),
#  (17.257516159163153, 17.1),
#  (14.812817151730531, 14.5),
#  (10.235610562175939, 11.3),
#  (17.223895544129697, 17.4),
#  (12.1856062341163, 16.7),
#  (17.75702243966019, 13.4),
#  (12.949274489876196, 15.9),
#  (13.237451190162949, 12.9),
#  (20.874133747761903, 12.8),
#  (8.1415265400922, 9.5),
#  (17.03177774393853, 18.4),
#  (11.734129403667055, 10.7),
#  (10.168369332109028, 12.5),
#  (8.117511815068303, 8.5),
#  (12.070335554001598, 11.5),
#  (12.334497529264457, 11.9),
#  (15.960721007872765, 14.9),
#  (8.982041915928562, 10.1),
#  (18.86169979075941, 18.9),
#  (14.923284886840454, 19.6),
#  (18.44384357534362, 15.9),
#  (18.43423768533406, 23.2),
#  (18.174878655075986, 11.9),
# ...

# %%
arun2 = list(zip(arun,arun1))

# %%
arun2
# Out:
# [((array([21.70910292]), 'sales'), (17.03658068894331, 23.8))]

# %%
metrics.mean_absolute_error(y1_test,y1_pred)
# Out:
# 2.4643080986027908

# %%
metrics.mean_squared_error(y1_test,y1_pred)
# Out:
# 10.310069587813155

# %%
np.sqrt(metrics.mean_squared_error(y1_test,y1_pred))
# Out:
# 3.210929707703542
